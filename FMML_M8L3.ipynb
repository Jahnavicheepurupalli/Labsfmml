# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavicheepurupalli/Labsfmml/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 12:56:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  82.9MB/s    in 0.8s
#
# 2025-03-13 12:56:55 (82.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14076  1708.04745v1  Optimization problems with more than one objec...    cs
# 4430   1709.08868v1  This paper proposes a minimal contrastive dive...  stat
# 28699  1707.05471v1  Techniques for dense semantic correspondence h...    cs
# 7285   1711.07050v1  The variational autoencoder (VAE) is a popular...  stat
# 10966   1211.5901v1  We consider the inverse reinforcement learning...  stat
# ...             ...                                                ...   ...
# 6504   1702.08540v1  Many active learning methods belong to the ret...  stat
# 3055   1709.09882v1  We report on an extensive study of the current...    cs
# 11054   1312.5192v2  It has been recently shown that a large class ...  stat
# 36309   1206.3614v3  Linear active-power-only DC power flow approxi...    cs
# 25295  1507.04060v1  An algorithm to improve performance parameter ...    cs
#
#                                                    title  year  \
# 14076  Weight-based Fish School Search algorithm for ...  2017
# 4430   Learning Multi-grid Generative ConvNets by Min...  2017
# 28699  DCTM: Discrete-Continuous Transformation Match...  2017
# 7285   A Classifying Variational Autoencoder with App...  2017
# 10966  Bayesian learning of noisy Markov decision pro...  2012
# ...                                                  ...   ...
# 6504       Active Learning Using Uncertainty Information  2017
# 3055   Are we Done with Object Recognition? The iCub ...  2017
# 11054  Nonlinear Eigenproblems in Data Analysis - Bal...  2013
# 36309  A Linear-Programming Approximation of AC Power...  2012
# 25295  Unsupervised Decision Forest for Data Clusteri...  2015
#
#                                                 keywords
# 14076  [optimization, objective, attractive, research...
# 4430   [contrastive, divergence, generative, simultan...
# 28699  [techniques, correspondence, geometric, variat...
# 7285   [variational, autoencoder, probabilistic, gene...
# 10966  [reinforcement, predicting, mimicking, control...
# ...                                                  ...
# 6504   [retraining, approaches, unlabeled, classifica...
# 3055   [extensive, limitations, approaches, introduce...
# 11054  [relaxation, nonlinear, eigenproblem, algorith...
# 36309  [approximations, pervasive, approximations, ma...
# 25295  [algorithm, performance, parameter, unsupervis...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14076    [optimization, objective, attractive, research...
# 4430     [contrastive, divergence, generative, simultan...
# 28699    [techniques, correspondence, geometric, variat...
# 7285     [variational, autoencoder, probabilistic, gene...
# 10966    [reinforcement, predicting, mimicking, control...
#                                ...
# 20382    [computerized, interesting, promising, abiliti...
# 22717    [discriminated, graphical, graphical, providin...
# 30994    [estimation, simultaneously, stationary, recor...
# 276      [autoencoders, linguistic, representations, re...
# 37988    [nonconvex, penalization, nonparametric, formu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8682 words.
# Out of those 4532 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32f19ad9-1ab0-46a9-924e-3a7c95d36ed9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32f19ad9-1ab0-46a9-924e-3a7c95d36ed9")) {                    Plotly.newPlot(                        "32f19ad9-1ab0-46a9-924e-3a7c95d36ed9",                        [{"x":["adaptation","increases","algorithms","necessity","improving","generated","situations","reference","applicability","computational","competitiveness","optimization","intelligence","objectives","intersection","clustering","specialized","algorithm","decomposition","objective","metaheuristic","researchers","technique","techniques","performance","attractive","literature","conflicting","initialized","differences","obtaining","realistic","parameters","contrastive","initializing","generating","persistent","generative","probabilistic","iteration","divergence","synthesized","outperforms","subsequent","convolutional","separately","simultaneously","transformations","solutions","filtering","descriptor","efficiently","continuous","experimental","geometric","iteratively","variations","associated","semantically","practical","transformation","benchmarks","correspondence","framework","tremendous","regularization","deformations","extension","difficult","application","distribution","shortcoming","algorithmic","variational","outperform","different","incorporates","corresponding","polyphonic","especially","classifier","recurrent","variables","autoencoder","generation","sequential","sequences","classifying","predicting","inference","stateaction","statistical","essential","estimated","reinforcement","mimicking","expansion","controller","illustration","properties","simulation","parameter","predictions","processes","convergence","structure","posterior","procedure","instances","factorization","exponentially","functions","initialize","initialization","convexity","minimization","knowledge","selecting","guarantees","assumptions","procedures","considered","hyperparameter","important","conclusions","benchmarking","investigated","frequently","interesting","regression","terminology","quantifying","optimized","importance","carefully","hyperparameters","formalize","classification","alternative","consuming","appropriately","specified","discusses","evolution","exploration","mathematical","fundamental","particular","scientific","developmental","formation","mechanisms","evolutionary","commentary","development","understanding","curiosity","challenges","motivation","emphasize","organization","perspective","curvature","difference","intensity","evaluated","preserving","intensities","quantitatively","improvement","displacement","interpolate","interpolation","processing","registration","currently","technologies","applications","information","spatiotemporal","communications","delivering","collecting","activities","ubiquitous","population","locations","inferring","regulations","relationship","awareness","sentiment","increased","healthcare","consistently","optimistic","discussions","perception","education","expressed"],"y":[64,52,595,12,100,199,52,56,35,261,4,329,85,31,16,155,17,855,69,153,9,68,265,370,863,24,93,11,10,60,35,45,273,9,4,108,7,126,147,32,26,14,250,34,419,30,109,33,153,64,34,162,101,368,66,34,91,107,26,136,75,104,27,543,11,82,11,84,146,258,220,4,46,63,96,748,29,126,0,106,155,132,107,29,140,69,96,40,83,204,1,164,82,59,122,7,12,20,3,201,66,121,84,94,125,347,54,114,103,34,18,207,19,25,11,65,349,49,79,70,42,128,9,340,20,9,50,31,74,124,10,13,60,79,31,12,15,504,102,36,11,39,20,54,56,62,89,270,47,4,13,53,70,2,120,159,2,105,25,11,23,72,9,54,39,141,36,9,25,160,8,2,14,300,30,55,29,429,665,11,7,3,16,31,14,47,29,22,2,70,7,44,38,8,40,7,9,36,9,34],"type":"bar"},{"x":["adaptation","increases","algorithms","necessity", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4532,), (4532, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Skip</span> <span style=''>Thought</span> <span style=''>Memory</span> <span style=''>Networks</span> <br/><br/><span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.6551724137931034);'>Answering</span> <span style=''>(QA)</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>to</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.46699266503667486);'>processing</span> <span style=''>in</span> <span style=''>that</span> <span style=''>most</span> <span style=''>nlp</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>be</span> <span style=''>phrased</span> <span style=''>as</span> <span style=''>QA</span> <span style=''>(Kumar</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015)</span> <span style=''>Current</span> <span style=''>weakly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>memory</span> <span style=''>network</span> <span style=''>models</span> <span style=''>that</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>so</span> <span style=''>far</span> <span style=''>struggle</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.6551724137931034);'>answering</span> <span style='background-color:rgba(0, 255, 0, 0.32653061224489793);'>questions</span> <span style=''>that</span> <span style=''>involve</span> <span style='background-color:rgba(0, 255, 0, 0.3228346456692914);'>relations</span> <span style=''>among</span> <span style=''>multiple</span> <span style=''>entities</span> <span style=''>(such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>facebooks</span> <span style=''>bAbi</span> <span style=''>qa5</span> <span style=''>three</span> <span style=''>arg</span> <span style='background-color:rgba(0, 255, 0, 0.3228346456692914);'>relations</span> <span style=''>in</span> <span style=''>(Weston</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015))</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>multi</span> <span style=''>argument</span> <span style=''>multi</span> <span style=''>hop</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.3228346456692914);'>relations</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style=''>QA</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>jointly</span> <span style=''>learned</span> <span style=''>long</span> <span style=''>term</span> <span style=''>read</span> <span style=''>write</span> <span style=''>memory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>attentive</span> <span style='background-color:rgba(255, 0, 0, 0.318864774624374);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>memory</span> <span style=''>networks</span> <span style=''>(MemN2N)</span> <span style=''>(Sukhbaatar</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015)</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>sentence</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.4050991501416431);'>representations</span> <span style=''>encoded</span> <span style=''>by</span> <span style=''>a< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bivariate</span> <span style=''>ranks</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommender</span> <span style=''>system</span> <span style=''>based</span> <span style=''>on</span> <span style=''>ranks</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>where</span> <span style=''>an</span> <span style=''>experts</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>a</span> <span style=''>users</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>those</span> <span style=''>objects</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>to</span> <span style=''>make</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>users</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>all</span> <span style=''>objects</span> <span style=''>The</span> <span style=''>rankings</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>induced</span> <span style=''>by</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style=''>grades</span> <span style=''>assigned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>expert</span> <span style=''>and</span> <span style=''>the</span> <span style=''>user</span> <span style=''>to</span> <span style=''>the</span> <span style=''>objects</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>between</span> <span style=''>the</span> <span style=''>expert</span> <span style=''>and</span> <span style=''>user</span> <span style=''>grades</span> <span style=''>is</span> <span style=''>modelled</span> <span style=''>by</span> <span style=''>a</span> <span style=''>copula</span> <span style=''>in</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>family</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>on</span> <span style=''>the</span> <span style=''>copula</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>the</span> <span style=''>users</span> <span style=''>complete</span> <span style=''>ranking</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>by</span> <span style=''>the</span> <span style=''>mode</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>users</span> <span style=''>complete</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>on</span> <span style=''>the</span> <span style=''>experts</span> <span style=''>complete</span> <span style=''>and</span> <span style=''>the</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.4090909090909091);'>Divergence</span> <span style=''>Bound</span> <span style=''>for</span> <span style=''>Hybrids</span> <span style=''>of</span> <span style=''>MCMC</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5153846153846153);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.318864774624374);'>Inference</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Langevin</span> <span style=''>Dynamics</span> <span style=''>and</span> <span style=''>SGVI</span> <br/><br/><span style=''>Two</span> <span style=''>popular</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.318864774624374);'>inference</span> <span style=''>are</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5153846153846153);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.318864774624374);'>inference</span> <span style=''>MCMC</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>be</span> <span style=''>accurate</span> <span style=''>if</span> <span style=''>run</span> <span style=''>for</span> <span style=''>a</span> <span style=''>long</span> <span style=''>enough</span> <span style=''>time</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.5153846153846153);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.318864774624374);'>inference</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>give</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.4461538461538461);'>approximations</span> <span style=''>at</span> <span style=''>shorter</span> <span style=''>time</span> <span style=''>horizons</span> <span style=''>However</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>time</span> <span style=''>needed</span> <span style=''>for</span> <span style=''>MCMC</span> <span style=''>to</span> <span style=''>exceed</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5153846153846153);'>variational</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>be</span> <span style=''>quite</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivating</span> <span style=''>more</span> <span style=''>fine</span> <span style=''>grained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tradeoffs</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>derives</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.5153846153846153);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>a</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4090909090909091);'>divergence</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style=''>the</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consistency</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prototype</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Space</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>in</span> <span style=''>general</span> <span style=''>terms</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>prove</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimisation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prototype</span> <span style=''>or</span> <span style=''>distance</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>was</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>Divisive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretic</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>model</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>space</span> <span style=''>with</span> <span style=''>Kullback</span> <span style=''>Leibler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>which</span> <span style=''>may</span> <span style=''>be</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimisation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>Also</span> <span style=''>we</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricting</span> <span style=''>creation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style=''>clusters</span> <span style=''>which</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>or</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>essentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>with</span> <span style=''>existing</span> <span style=''>clusters</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12275765036932818)
# 	representation (0.1266268026732325)
# 	architecture (0.08688005627857896)
# 	experimental (0.12944073162152656)
# 	processing (0.10552233556102708)
# 	segmentation (0.06964474147027788)
# 	different (0.2631023566654942)
# 	detection (0.1266268026732325)
# 	recognition (0.13542033063665143)
# 	convolutional (0.14737952866690116)
#
# Some Statistics words are:
# 	stochastic (0.14052120592743997)
# 	estimation (0.17526826775677057)
# 	theoretical (0.16198262646908534)
# 	variables (0.14512008175779254)
# 	statistical (0.1655595298926929)
# 	algorithm (0.41236586612161474)
# 	distribution (0.1890648952478283)
# 	dimensional (0.19059785385794584)
# 	inference (0.20183955033214104)
# 	regression (0.1773122125702606)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31378fa2-3bc3-44ab-83b6-fee0570c8931" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31378fa2-3bc3-44ab-83b6-fee0570c8931")) {                    Plotly.newPlot(                        "31378fa2-3bc3-44ab-83b6-fee0570c8931",                        [{"x":["adaptation","increases","algorithms","necessity","improving","generated","situations","reference","applicability","computational","competitiveness","optimization","intelligence","objectives","intersection","clustering","specialized","algorithm","decomposition","objective","metaheuristic","researchers","technique","techniques","performance","attractive","literature","conflicting","initialized","differences","obtaining","realistic","parameters","contrastive","initializing","generating","persistent","generative","probabilistic","iteration","divergence","synthesized","outperforms","subsequent","convolutional","separately","simultaneously","transformations","solutions","filtering","descriptor","efficiently","continuous","experimental","geometric","iteratively","variations","associated","semantically","practical","transformation","benchmarks","correspondence","framework","tremendous","regularization","deformations","extension","difficult","application","distribution","shortcoming","algorithmic","variational","outperform","different","incorporates","corresponding","polyphonic","especially","classifier","recurrent","variables","autoencoder","generation","sequential","sequences","classifying","predicting","inference","stateaction","statistical","essential","estimated","reinforcement","mimicking","expansion","controller","illustration","properties","simulation","parameter","predictions","processes","convergence","structure","posterior","procedure","instances","factorization","exponentially","functions","initialize","initialization","convexity","minimization","knowledge","selecting","guarantees","assumptions","procedures","considered","hyperparameter","important","conclusions","benchmarking","investigated","frequently","interesting","regression","terminology","quantifying","optimized","importance","carefully","hyperparameters","formalize","classification","alternative","consuming","appropriately","specified","discusses","evolution","exploration","mathematical","fundamental","particular","scientific","developmental","formation","mechanisms","evolutionary","commentary","development","understanding","curiosity","challenges","motivation","emphasize","organization","perspective","curvature","difference","intensity","evaluated","preserving","intensities","quantitatively","improvement","displacement","interpolate","interpolation","processing","registration","currently","technologies","applications","information","spatiotemporal","communications","delivering","collecting","activities","ubiquitous","population","locations","inferring","regulations","relationship","awareness","sentiment","increased","healthcare","consistently","optimistic","discussions","perception","education","expressed","artificial","pessimistic","discussion","prevalence","engagement","association","opportunities","automation","residents","recommender","behaviour","converted","decreasing","consumption","prioritized","recommendation","approximation","desirable","approached","eigendecomposition","interpret","interpretation","benchmark","embedding","typically","sentiments","semidefinite","sophisticated","categorized","competitive","submatrix","principled","incorporate","experiments","blockwise","meaningful","possibilities","hierarchy","penalized","classifiers","hierarchical","distinguish","previously","ultrametric","plausible","expertise","automatically","controllers","generalizes","generalizing","expensive","baselines", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	polyphonic
# 	emphstatistical
# 	changepoints
# 	changepoint
# 	sparsification
# 	dissimilarities
# 	unspecified
# 	semiparametric
# 	immigration
# 	emphmulti
# 	preconditioning
# 	couplings
# 	neuroimage
# 	compensating
# 	stationarities
# 	ellipsoid
# 	precisions
# 	orthogonality
# 	bivariate
# 	statisticians
# Some words which never appear in Statistics papers:
# 	metaheuristic
# 	curiosity
# 	discussions
# 	categorized
# 	endoscopic
# 	commercially
# 	rewarding
# 	repeatable
# 	defeasible
# 	confusions
# 	possibilistic
# 	nonmonotonic
# 	upscaling
# 	perceived
# 	referenced
# 	compiling
# 	radiography
# 	operative
# 	overlapped
# 	inheritance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0337964929312547e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
